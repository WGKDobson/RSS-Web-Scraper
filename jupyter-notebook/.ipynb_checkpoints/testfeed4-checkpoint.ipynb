# %%
import feedparser

def parseRSS(rss_url):
    return feedparser.parse(rss_url)

def getHeadlines(rss_url):
    headlines = []
    feed = parseRSS(rss_url)
    for newsitem in feed['items']:
        headlines.append(newsitem['title'])
    return headlines

allheadlines = []

newsurls = {'googlenews':'https://news.google.com/news/rss/?h1=en&amp;ned=us&amp;g1=US'}

for key, url in newsurls.items():
    allheadlines.extend(getHeadlines(url))
    
for hl in allheadlines:
    print(hl)
    print(' ')
# Out:
# Amy Coney Barrett's Confirmation Hearing Style: What It Means - The New York Times
#
# These were the busiest, slowest polling locations in Bexar County on the first day of early voting - KSAT San Antonio
#
# NBC schedules Trump town hall at the same time as Biden's on ABC, sparking outrage - CNN
#
# Smoking-gun email reveals how Hunter Biden introduced Ukrainian businessman to VP dad - New York Post
#
# Fox News portrayed it as one of the biggest scandals in American history. Then it fell apart - CNN
#
# White woman in Central Park called 911 a second time on Black bird-watcher, prosecutors say - USA TODAY
#
# Antifa shooter Michael Reinoehl had loaded gun in pocket during deadly arrest: police - New York Post
#
# President Trump to host campaign rally in Des Moines today - KCCI Des Moines
#
# North Carolina poll shows Cunningham up 4 points despite scandal - POLITICO
#
# Gun-Waving St. Louis Couple Plead Not Guilty To 2 Felony Charges - NPR
#
# Russia calls on Armenia and Azerbaijan to respect ceasefire in Nagorno-Karabakh - The Guardian
#
# 2 US citizens released by Iran-backed militants in Yemen - The Associated Press
#
# Trump Vs. Biden: How Russia Sees The U.S. Election - NPR
#
# Woman close to Vatican cardinal arrested in corruption probe - Fox News
#
# YouTube bans misinformation about Covid vaccinations - The Guardian
#
# Dow Jones Slips On Dim Stimulus Prospects; These Two Growth Stocks Break Out - Investor's Business Daily
#
# Bill Gates on coronavirus: 'The fall is going to be worse than the summer' - Yahoo Finance
#
# Warren rips Disney over layoffs amid reported restoration of executive pay | TheHill - The Hill
#
# iPhone 12 and 12 Pro 5G: Apple unveils super-speedy new phone lineup - CNET
#
# 29 Amazon Prime Day Fashion Deals You’ll Actually Want To Buy - Forbes
#
# The OnePlus 8T arrives with two batteries, a 120Hz flat display, and 65W fast charging - PhoneArena
#
# Google Recorder 2.0 debuts on the Pixel 5 with transcript corrections, audio editing, and more - XDA Developers
#
# 'Hillbilly Elegy' Trailer: Amy Adams and Glenn Close Deliver Appalachian Angst in Ron Howard's Oscar Contender - /FILM
#
# 'Bachelorette' front-runner Dale Moss reacts to Clare Crawley: 'I felt that' - Page Six
#
# Stevie Nicks wins the 'Dreams' Tik Tok challenge - CNN
#
# Meghan, Duchess of Sussex, Speaks Out Against Harmful Online Behavior - The New York Times
#
# Denver Broncos RB Melvin Gordon cited for DUI - ESPN
#
# Adam Gase: It’s irrelevant if we misused Le’Veon Bell - NBC Sports - NFL
#
# Fantasy Football Kicker Guide Week 6 (2020) - FantasyPros
#
# Steve Sax says he feels for Houston Astros' struggling Jose Altuve - ESPN
#
# Blastoff! Cosmonaut snaps amazing photos of Soyuz rocket launch from space - Space.com
#
# NASA Announces Partners to Advance 2020 'Tipping Point' Technologies - NASA
#
# Room-temperature superconductivity in a carbonaceous sulfur hydride - Nature.com
#
# Rare magnetism found in the world's strongest material - Live Science
#
# 89-year-old Dutch woman dies after reinfected with coronavirus - The Jerusalem Post
#
# People with blood type O may have lower risk of Covid-19 infection and severe illness, two new studies suggest - CNN
#
# CDC Director Robert Redfield warns that Thanksgiving gatherings could cause COVID cases to soar - Daily Mail
#
# Coronavirus and flu: Are we headed for a double epidemic? | COVID-19 Special - DW News
